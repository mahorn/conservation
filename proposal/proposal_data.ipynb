# %%
import pandas as pd

# %%
file_path = './WDPA_Feb2019_BRA-csv.csv'

with open(file_path) as file:
    rows = file.readlines()

# %%
type(rows)
# Out:
# list

# %%
rows
# Out:
# ['\ufeffTYPE,WDPAID,WDPA_PID,PA_DEF,NAME,ORIG_NAME,DESIG,DESIG_ENG,DESIG_TYPE,IUCN_CAT,INT_CRIT,MARINE,REP_M_AREA,GIS_M_AREA,REP_AREA,GIS_AREA,NO_TAKE,NO_TK_AREA,STATUS,STATUS_YR,GOV_TYPE,OWN_TYPE,MANG_AUTH,MANG_PLAN,VERIF,METADATAID,SUB_LOC,PARENT_ISO3,ISO3\n',
#  'Polygon,34036,34036,1,Rio Mequens,Rio Mequens,Terra Indígena,Indigenous Area,National,Not Reported,Not Applicable,0,0,0,1075.530101,1084.30230858,Not Applicable,0,Designated,1997,Indigenous peoples,Not Reported,Not Reported,Not Reported,State Verified,905,BR-RO,BRA,BRA\n',
#  'Polygon,352514,352514,1,Nonoai/Rio da Várzea,Nonoai/Rio da Várzea,Terra Indígena,Indigenous Area,National,Not Reported,Not Applicable,0,0,0,164.154443,164.745279369,Not Applicable,0,Designated,2003,Indigenous peoples,Not Reported,Not Reported,Not Reported,State Verified,905,BR-RS,BRA,BRA\n',
# ...

# %%
len(rows)
# Out:
# 2300

# %%
count = 0
for row in rows:
    print(row)
    count+=1
    if count == 10:
        break
# Out:
# ﻿TYPE,WDPAID,WDPA_PID,PA_DEF,NAME,ORIG_NAME,DESIG,DESIG_ENG,DESIG_TYPE,IUCN_CAT,INT_CRIT,MARINE,REP_M_AREA,GIS_M_AREA,REP_AREA,GIS_AREA,NO_TAKE,NO_TK_AREA,STATUS,STATUS_YR,GOV_TYPE,OWN_TYPE,MANG_AUTH,MANG_PLAN,VERIF,METADATAID,SUB_LOC,PARENT_ISO3,ISO3
#
# Polygon,34036,34036,1,Rio Mequens,Rio Mequens,Terra Indígena,Indigenous Area,National,Not Reported,Not Applicable,0,0,0,1075.530101,1084.30230858,Not Applicable,0,Designated,1997,Indigenous peoples,Not Reported,Not Reported,Not Reported,State Verified,905,BR-RO,BRA,BRA
#
# Polygon,352514,352514,1,Nonoai/Rio da Várzea,Nonoai/Rio da Várzea,Terra Indígena,Indigenous Area,National,Not Reported,Not Applicable,0,0,0,164.154443,164.745279369,Not Applicable,0,Designated,2003,Indigenous peoples,Not Reported,Not Reported,Not Reported,State Verified,905,BR-RS,BRA,BRA
#
# ...

# %%
import pandas as df

# %%
df = pd.read_csv('./WDPA_Feb2019_BRA-csv.csv')

# %%
df.head(11)
# Out:
#        TYPE  WDPAID  WDPA_PID  PA_DEF                       NAME  \
# 0   Polygon   34036     34036       1                Rio Mequens
# 1   Polygon  352514    352514       1       Nonoai/Rio da Várzea
# 2   Polygon  352364    352364       1                   Aripuanã
# 3   Polygon  352262    352262       1                     Balaio
# 4   Polygon  115539    115539       1      Kanamari do Rio Juruá
# 5   Polygon  115418    115418       1  Tenharim do Igarapé Preto
# 6   Polygon  352460    352460       1                Pilad Rebuá
# 7   Polygon   67817     67817       1             Lagoa do Peixe
# 8   Polygon  352401    352401       1       Córrego João Pereira
# 9   Polygon  352273    352273       1            Jaminaua/Envira
# 10  Polygon   94063     94063       1            Ilha do Bananal
#
#                     ORIG_NAME  \
# 0                 Rio Mequens
# 1        Nonoai/Rio da Várzea
# 2                    Aripuanã
# 3                      Balaio
# ...
